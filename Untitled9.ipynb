# %% [markdown]
# <a href="https://colab.research.google.com/github/deepthiburra/chat_app.backend/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from transformers import ( AutoTokenizer,AutoModelForCausalLM,
    Trainer,TrainingArguments,DataCollatorForLanguageModeling
)
from peft import LoraConfig,get_peft_model
import pandas as pd
from datasets import load_dataset
model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"


model = AutoModelForCausalLM.from_pretrained(
    model_name
)
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
pip install torchao
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -y

# %%
pip install torchao=0.16.0
# Out:
# ERROR: Invalid requirement: 'torchao=0.16.0': Expected end or semicolon (after name and no valid version specifier)
#     torchao=0.16.0
#            ^
# Hint: = is not a valid operator. Did you mean == ?

# %%
import pandas as p
df = pd.DataFrame({
    "Question": [
        "What is insurance?",
        "What are the different types of insurance?",
        "What is health insurance?",
        "What is life insurance?",
        "What is vehicle insurance?",
        "What is a premium?",
        "What is an insurance policy?",
        "What is an insurance claim?",
        "What is coverage in insurance?",
        "What is a deductible?",
        "Who is an insurer?",
        "Who is the insured?",
        "What is policy tenure?",
        "What is policy renewal?",
        "What is cashless hospitalization?",
        "What is a network hospital?",
        "Who is a nominee?",
        "What is the sum insured?",
        "What is a waiting period?",
        "What is co-payment?",
        "What is a no-claim bonus?",
        "Can I cancel my insurance policy?",
        "What documents are required for an insurance claim?",
        "What is travel insurance?",
        "What is home insurance?",
        "What is accidental insurance?",
        "What is critical illness insurance?",
        "How is the insurance premium calculated?",
        "Can I buy insurance online?",
        "Can I have multiple insurance policies?",
        "What is term insurance?",
        "What is whole life insurance?",
        "What is ULIP?",
        "What happens if I miss a premium payment?",
        "What happens if I miss a premium payment?",
        "Can I revive a lapsed policy?",
        "What is the grace period?",
        "What is underwriting?",
        "What is the claim settlement ratio?",
        "Why is claim settlement ratio important?",
        "What is third-party insurance?",
        "Is third-party vehicle insurance mandatory?",
        "What is comprehensive insurance?",
        "What is a policy endorsement?",
        "Can I change my nominee?",
        "What is insurance fraud?",
        "What is a reimbursement claim?",
        "How long does claim settlement take?",
        "What are policy exclusions?",
        "Are pre-existing diseases covered?",
        "What is maternity insurance coverage?",
        "Can senior citizens buy health insurance?",
        "What is family floater insurance?",
        "Can children be included in health insurance?",
        "What is insurance portability?",
        "Can I pay my premium monthly?",
        "What payment methods are accepted?",
        "How do I renew my insurance policy?",
        "Can I increase my insurance coverage?",
        "What is policy maturity?",
        "What is a maturity benefit?",
        "What is a death benefit?",
        "Can I surrender my insurance policy?",
        "What is surrender value?",
        "Can NRIs buy insurance?",
        "What is group insurance?",
        "Who needs business insurance?",
        "What is fire insurance?",
        "What is marine insurance?",
        "What is cyber insurance?",
        "Does insurance cover natural disasters?",
        "What is personal accident insurance?",
        "Can I track my insurance claim online?",
        "What is a policy schedule?",
        "Can I update my address in the policy?",
        "Can I update my mobile number?",
        "What is an e-policy?",
        "Is an e-policy legally valid?",
        "What is an insurance ID card?",
        "How can I contact customer support?",
        "What is the free-look period?",
        "Can I cancel during the free-look period?",
        "Who is an insurance broker?",
        "Who is an insurance agent?",
        "What is policy servicing?",
        "Can vehicle insurance be transferred?",
        "What is claim rejection?",
        "Why are insurance claims rejected?",
        "What is policy issuance?",
        "Can I download my insurance policy online?",
        "What is a renewal reminder?",
        "What is risk assessment?",
        "Can jewelry be insured?",
        "Is pet insurance available?",
        "What is crop insurance?",
        "What is livestock insurance?",
        "Can students buy health insurance?",
        "What is disability insurance?",
        "How do I compare insurance policies?",
        "What should I check before buying insurance?",
        "Why is insurance important?"
    ],
    "Answer": [
        "Insurance provides financial protection against unexpected losses.",
        "Health, Life, Vehicle, Home, Travel, Business, and Accident insurance.",
        "Health insurance covers medical expenses and hospitalization costs.",
        "Life insurance provides financial support to beneficiaries after the policyholder's death.",
        "Vehicle insurance covers damages, theft, and third-party liabilities.",
        "A premium is the amount paid to maintain an insurance policy.",
        "An insurance policy is a legal contract between the insurer and the insured.",
        "An insurance claim is a request for compensation from the insurer.",
        "Coverage refers to the risks protected under the policy.",
        "A deductible is the amount paid by the insured before insurance starts paying.",
        "The insurer is the company providing insurance services.",
        "The insured is the person covered under the policy.",
        "Policy tenure is the duration of the insurance policy.",
        "Policy renewal extends the validity of the insurance policy.",
        "Cashless hospitalization allows treatment without upfront payment at network hospitals.",
        "A network hospital has an agreement with the insurance company.",
        "A nominee receives policy benefits after the insured's death.",
        "Sum insured is the maximum amount payable by the insurer.",
        "A waiting period is the time before certain benefits become available.",
        "Co-payment is the portion of expenses paid by the insured.",
        "A no-claim bonus is a reward for not making claims.",
        "Yes, policies can be canceled according to the insurer's terms.",
        "Claim form, policy document, ID proof, bills, and medical reports.",
        "Travel insurance covers travel-related emergencies and losses.",
        "Home insurance protects your house and belongings.",
        "Accidental insurance provides compensation for accidental injuries or death.",
        "Critical illness insurance covers specified serious illnesses.",
        "Premium depends on age, health, coverage amount, and risk factors.",
        "Yes, insurance can be purchased online.",
        "Yes, you can own multiple insurance policies.",
        "Term insurance provides coverage for a fixed period.",
        "Whole life insurance provides lifetime coverage.",
        "ULIP combines insurance protection with investment benefits.",
        "The policy may lapse if the premium is not paid.",
        "Yes, a lapsed policy can often be revived within a specified period.",
        "The grace period is extra time given to pay the premium.",
        "Underwriting is the process of evaluating insurance risk.",
        "It is the percentage of claims settled by an insurer.",
        "It indicates the insurer's reliability in settling claims.",
        "Third-party insurance covers damages caused to others.",
        "Yes, it is mandatory for vehicles in many countries.",
        "Comprehensive insurance covers own damage and third-party liability.",
        "A policy endorsement is a change made to an existing policy.",
        "Yes, nominees can be changed anytime.",
        "Insurance fraud is providing false information for financial gain.",
        "A reimbursement claim is settled after the insured pays expenses first.",
        "Claim settlement usually takes a few days to weeks.",
        "Policy exclusions are situations not covered by insurance.",
        "Yes, after the applicable waiting period.",
        "It covers pregnancy and childbirth-related expenses.",
        "Yes, senior citizen health insurance plans are available.",
        "Family floater insurance covers all family members under one policy.",
        "Yes, children can be included in family health plans.",
        "Insurance portability allows switching insurers without losing benefits.",
        "Yes, many insurers allow monthly premium payments.",
        "Online banking, debit cards, credit cards, UPI, and net banking.",
        "Renew online or through the insurance company before expiry.",
        "Yes, you can upgrade your coverage.",
        "Policy maturity is when the insurance term ends.",
        "Maturity benefit is paid after policy completion.",
        "Death benefit is paid to the nominee after the insured's death.",
        "Yes, eligible policies can be surrendered.",
        "Surrender value is the amount received after surrendering a policy.",
        "Yes, NRIs can buy insurance subject to eligibility.",
        "Group insurance covers multiple people under one policy.",
        "Businesses needing protection from financial risks require business insurance.",
        "Fire insurance covers damages caused by fire.",
        "Marine insurance covers goods transported by sea.",
        "Cyber insurance protects against cyber threats and data breaches.",
        "Yes, if the policy includes natural disaster coverage.",
        "It covers accidental death and disability.",
        "Yes, most insurers provide online claim tracking.",
        "A policy schedule summarizes the policy details.",
        "Yes, address updates can be requested.",
        "Yes, mobile number updates are allowed.",
        "An e-policy is a digital version of the insurance policy.",
        "Yes, e-policies are legally valid.",
        "It is proof of active insurance coverage.",
        "Through phone, email, website, or mobile app.",
        "It is the period during which a new policy can be canceled.",
        "Yes, subject to the insurer's conditions.",
        "An insurance broker helps customers compare and choose policies.",
        "An insurance agent sells insurance policies on behalf of an insurer.",
        "Policy servicing includes updates and maintenance of a policy.",
        "Yes, vehicle insurance can be transferred to the new owner.",
        "Claim rejection means the insurer has denied the claim.",
        "Claims may be rejected due to exclusions, fraud, or missing documents.",
        "Policy issuance is the process of creating and activating a policy.",
        "Yes, policies can usually be downloaded from the insurer's portal.",
        "It is a notification sent before policy expiry.",
        "Risk assessment evaluates the likelihood of future losses.",
        "Yes, valuable jewelry can be insured.",
        "Yes, pet insurance is available for dogs and cats.",
        "Crop insurance protects farmers from crop losses.",
        "Livestock insurance covers farm animals against risks.",
        "Yes, student health insurance plans are available.",
        "Disability insurance provides financial support in case of disability.",
        "Compare coverage, premium, exclusions, benefits, and claim ratio.",
        "Check coverage, exclusions, premium, claim process, and insurer reputation.",
        "Insurance provides financial security and peace of mind."
    ]
})

print(df)

df.to_json("train_data.json", orient="records", indent=4)
#load our custom dataset
dataset=load_dataset("json",data_files="train_data.json")
print(dataset)

#data preprocessing

def formatting(data):
  return {"text":f"Question: {data['Question']} Answer: {data['Answer']}"}
dataset=dataset['train'].map(formatting)
print(dataset)

data_collector=DataCollatorForLanguageModeling(tokenizer,mlm=False)
#Training arguments
training_args=TrainingArguments(
    output_dir="./outputs",
    num_train_epochs=5,
    per_device_train_batch_size=1,
    learning_rate=2e-4,
    logging_steps=1,
    save_strategy="steps",
    fp16=True
)#tokenization
tokenizer=AutoTokenizer.from_pretrained(model_name,trust_remote_code=True)
tokenizer.pad_token=tokenizer.eos_token
def tokenize(prompt):
  result=tokenizer(prompt['text'],padding="max_length",truncation=True,
                   max_length=128)
  result['Labels']=result['input_ids'].copy()
  return result
dataset=dataset.map(tokenize)
print(dataset)
#config and save LoRA
config=LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj","v_proj"],
    bias="none",
    task_type="CAUSAL_LM"
)
model=get_peft_model(model,config)
print(model.print_trainable_parameters())
#Data collector
trainer=Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
    data_collator=data_collector
)
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_529/1375406095.py in <cell line: 0>()
#       1 import pandas as p
# ----> 2 df = pd.DataFrame({
#       3     "Question": [
#       4         "What is insurance?",
#       5         "What are the different types of insurance?",
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     776         elif isinstance(data, dict):
#     777             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779         elif isinstance(data, ma.MaskedArray):
#     780             from numpy.ma import mrecords
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
pip install torchao==0.16.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 36.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
# ...

# %%
import pandas as pd

df = pd.DataFrame({
    "Question": [
        "What is insurance?",
        "What are the different types of insurance?",
        "What is health insurance?",
        "What is life insurance?",
        "What is vehicle insurance?",
        "What is a premium?",
        "What is an insurance policy?",
        "What is an insurance claim?",
        "What is coverage in insurance?",
        "What is a deductible?",
        "Who is an insurer?",
        "Who is the insured?",
        "What is policy tenure?",
        "What is policy renewal?",
        "What is cashless hospitalization?",
        "What is a network hospital?",
        "Who is a nominee?",
        "What is the sum insured?",
        "What is a waiting period?",
        "What is co-payment?",
        "What is a no-claim bonus?",
        "Can I cancel my insurance policy?",
        "What documents are required for an insurance claim?",
        "What is travel insurance?",
        "What is home insurance?",
        "What is accidental insurance?",
        "What is critical illness insurance?",
        "How is the insurance premium calculated?",
        "Can I buy insurance online?",
        "Can I have multiple insurance policies?",
        "What is term insurance?",
        "What is whole life insurance?",
        "What is ULIP?",
        "What happens if I miss a premium payment?",
        "Can I revive a lapsed policy?",
        "What is the grace period?",
        "What is underwriting?",
        "What is the claim settlement ratio?",
        "Why is claim settlement ratio important?",
        "What is third-party insurance?",
        "Is third-party vehicle insurance mandatory?",
        "What is comprehensive insurance?",
        "What is a policy endorsement?",
        "Can I change my nominee?",
        "What is insurance fraud?",
        "What is a reimbursement claim?",
        "How long does claim settlement take?",
        "What are policy exclusions?",
        "Are pre-existing diseases covered?",
        "What is maternity insurance coverage?",
        "Can senior citizens buy health insurance?",
        "What is family floater insurance?",
        "Can children be included in health insurance?",
        "What is insurance portability?",
        "Can I pay my premium monthly?",
        "What payment methods are accepted?",
        "How do I renew my insurance policy?",
        "Can I increase my insurance coverage?",
        "What is policy maturity?",
        "What is a maturity benefit?",
        "What is a death benefit?",
        "Can I surrender my insurance policy?",
        "What is surrender value?",
        "Can NRIs buy insurance?",
        "What is group insurance?",
        "Who needs business insurance?",
        "What is fire insurance?",
        "What is marine insurance?",
        "What is cyber insurance?",
        "Does insurance cover natural disasters?",
        "What is personal accident insurance?",
        "Can I track my insurance claim online?",
        "What is a policy schedule?",
        "Can I update my address in the policy?",
        "Can I update my mobile number?",
        "What is an e-policy?",
        "Is an e-policy legally valid?",
        "What is an insurance ID card?",
        "How can I contact customer support?",
        "What is the free-look period?",
        "Can I cancel during the free-look period?",
        "Who is an insurance broker?",
        "Who is an insurance agent?",
        "What is policy servicing?",
        "Can vehicle insurance be transferred?",
        "What is claim rejection?",
        "Why are insurance claims rejected?",
        "What is policy issuance?",
        "Can I download my insurance policy online?",
        "What is a renewal reminder?",
        "What is risk assessment?",
        "Can jewelry be insured?",
        "Is pet insurance available?",
        "What is crop insurance?",
        "What is livestock insurance?",
        "Can students buy health insurance?",
        "What is disability insurance?",
        "How do I compare insurance policies?",
        "What should I check before buying insurance?",
        "Why is insurance important?"
    ],
    "Answer": [
        "Insurance provides financial protection against unexpected losses.",
        "Health, Life, Vehicle, Home, Travel, Business, and Accident insurance.",
        "Health insurance covers medical expenses and hospitalization costs.",
        "Life insurance provides financial support to beneficiaries after the policyholder's death.",
        "Vehicle insurance covers damages, theft, and third-party liabilities.",
        "A premium is the amount paid to maintain an insurance policy.",
        "An insurance policy is a legal contract between the insurer and the insured.",
        "An insurance claim is a request for compensation from the insurer.",
        "Coverage refers to the risks protected under the policy.",
        "A deductible is the amount paid by the insured before insurance starts paying.",
        "The insurer is the company providing insurance services.",
        "The insured is the person covered under the policy.",
        "Policy tenure is the duration of the insurance policy.",
        "Policy renewal extends the validity of the insurance policy.",
        "Cashless hospitalization allows treatment without upfront payment at network hospitals.",
        "A network hospital has an agreement with the insurance company.",
        "A nominee receives policy benefits after the insured's death.",
        "Sum insured is the maximum amount payable by the insurer.",
        "A waiting period is the time before certain benefits become available.",
        "Co-payment is the portion of expenses paid by the insured.",
        "A no-claim bonus is a reward for not making claims.",
        "Yes, policies can be canceled according to the insurer's terms.",
        "Claim form, policy document, ID proof, bills, and medical reports.",
        "Travel insurance covers travel-related emergencies and losses.",
        "Home insurance protects your house and belongings.",
        "Accidental insurance provides compensation for accidental injuries or death.",
        "Critical illness insurance covers specified serious illnesses.",
        "Premium depends on age, health, coverage amount, and risk factors.",
        "Yes, insurance can be purchased online.",
        "Yes, you can own multiple insurance policies.",
        "Term insurance provides coverage for a fixed period.",
        "Whole life insurance provides lifetime coverage.",
        "ULIP combines insurance protection with investment benefits.",
        "The policy may lapse if the premium is not paid.",
        "Yes, a lapsed policy can often be revived within a specified period.",
        "The grace period is extra time given to pay the premium.",
        "Underwriting is the process of evaluating insurance risk.",
        "It is the percentage of claims settled by an insurer.",
        "It indicates the insurer's reliability in settling claims.",
        "Third-party insurance covers damages caused to others.",
        "Yes, it is mandatory for vehicles in many countries.",
        "Comprehensive insurance covers own damage and third-party liability.",
        "A policy endorsement is a change made to an existing policy.",
        "Yes, nominees can be changed anytime.",
        "Insurance fraud is providing false information for financial gain.",
        "A reimbursement claim is settled after the insured pays expenses first.",
        "Claim settlement usually takes a few days to weeks.",
        "Policy exclusions are situations not covered by insurance.",
        "Yes, after the applicable waiting period.",
        "It covers pregnancy and childbirth-related expenses.",
        "Yes, senior citizen health insurance plans are available.",
        "Family floater insurance covers all family members under one policy.",
        "Yes, children can be included in family health plans.",
        "Insurance portability allows switching insurers without losing benefits.",
        "Yes, many insurers allow monthly premium payments.",
        "Online banking, debit cards, credit cards, UPI, and net banking.",
        "Renew online or through the insurance company before expiry.",
        "Yes, you can upgrade your coverage.",
        "Policy maturity is when the insurance term ends.",
        "Maturity benefit is paid after policy completion.",
        "Death benefit is paid to the nominee after the insured's death.",
        "Yes, eligible policies can be surrendered.",
        "Surrender value is the amount received after surrendering a policy.",
        "Yes, NRIs can buy insurance subject to eligibility.",
        "Group insurance covers multiple people under one policy.",
        "Businesses needing protection from financial risks require business insurance.",
        "Fire insurance covers damages caused by fire.",
        "Marine insurance covers goods transported by sea.",
        "Cyber insurance protects against cyber threats and data breaches.",
        "Yes, if the policy includes natural disaster coverage.",
        "It covers accidental death and disability.",
        "Yes, most insurers provide online claim tracking.",
        "A policy schedule summarizes the policy details.",
        "Yes, address updates can be requested.",
        "Yes, mobile number updates are allowed.",
        "An e-policy is a digital version of the insurance policy.",
        "Yes, e-policies are legally valid.",
        "It is proof of active insurance coverage.",
        "Through phone, email, website, or mobile app.",
        "It is the period during which a new policy can be canceled.",
        "Yes, subject to the insurer's conditions.",
        "An insurance broker helps customers compare and choose policies.",
        "An insurance agent sells insurance policies on behalf of an insurer.",
        "Policy servicing includes updates and maintenance of a policy.",
        "Yes, vehicle insurance can be transferred to the new owner.",
        "Claim rejection means the insurer has denied the claim.",
        "Claims may be rejected due to exclusions, fraud, or missing documents.",
        "Policy issuance is the process of creating and activating a policy.",
        "Yes, policies can usually be downloaded from the insurer's portal.",
        "It is a notification sent before policy expiry.",
        "Risk assessment evaluates the likelihood of future losses.",
        "Yes, valuable jewelry can be insured.",
        "Yes, pet insurance is available for dogs and cats.",
        "Crop insurance protects farmers from crop losses.",
        "Livestock insurance covers farm animals against risks.",
        "Yes, student health insurance plans are available.",
        "Disability insurance provides financial support in case of disability.",
        "Compare coverage, premium, exclusions, benefits, and claim ratio.",
        "Check coverage, exclusions, premium, claim process, and insurer reputation.",
        "Insurance provides financial security and peace of mind."
    ]
})

print(df)

df.to_json("train_data.json", orient="records", indent=4)
#load our custom dataset
dataset=load_dataset("json",data_files="train_data.json")
print(dataset)

#data preprocessing
def formatting(data):
  return {"text": f"Question: {data['Question']} Answer: {data['Answer']}"}
dataset = dataset['train'].map(formatting)
print(dataset)
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
def tokenize(prompt):
  result = tokenizer(prompt['text'], padding = 'max_length', truncation = True, max_length = 128)
  result['labels'] = result['input_ids'].copy()
  return result
dataset = dataset.map(tokenize)
print(dataset)
config = LoraConfig(
    r = 8,
    lora_alpha = 16,
    target_modules = ["q_proj", "v_proj"],
    bias = "none",
    task_type = "CAUSAL_LM"
)
model = get_peft_model(model, config)
print(model.print_trainable_parameters())
data_collator = DataCollatorForLanguageModeling(tokenizer, mlm = False)
training_args = TrainingArguments(
    output_dir = "./outputs",
    num_train_epochs = 5,
    per_device_train_batch_size = 1,
    learning_rate = 2e-4,
    logging_steps = 1,
    save_strategy = "steps",
    fp16 = True
)
trainer = Trainer(
    model = model,
    args = training_args,
    train_dataset = dataset,
    data_collator = data_collator
)
trainer.train()
model.save_pretrained("tinyllama-adapter")
tokenizer.save_pretrained("tinyllama_adapter")
device=next(model.parameters()).device
prompts="""
Question:
What is insurance?
Answer:
"""
inputs=tokenizer(prompts,return_tensors="pt")
inputs={k:v.to(device) for k,v in inputs.items()}
output=model.generate(**inputs,max_new_tokens=100)
print(tokenizer.decode(output[0],skip_special_tokens=True))
# Out:
#                                         Question  \
# 0                             What is insurance?
# 1     What are the different types of insurance?
# 2                      What is health insurance?
# 3                        What is life insurance?
# 4                     What is vehicle insurance?
# ..                                           ...
# 95            Can students buy health insurance?
# 96                 What is disability insurance?
# 97          How do I compare insurance policies?
# 98  What should I check before buying insurance?
# 99                   Why is insurance important?
#
#                                                Answer
# 0   Insurance provides financial protection agains...
# 1   Health, Life, Vehicle, Home, Travel, Business,...
# 2   Health insurance covers medical expenses and h...
# 3   Life insurance provides financial support to b...
# 4   Vehicle insurance covers damages, theft, and t...
# ...
